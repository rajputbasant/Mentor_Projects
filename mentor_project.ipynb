# %%
import numpy as np
import pandas as pd

# %%
col=list(map(chr, range(97, 117)))

# %%
new_file = pd.DataFrame(np.random.rand(100,20),columns=col)

# %%
print(new_file)
# Out:
#            a         b         c         d         e         f         g  \
# 0   0.813466  0.740831  0.591413  0.844582  0.451223  0.093426  0.046024
# 1   0.499812  0.633928  0.551171  0.448612  0.680644  0.467954  0.485881
# 2   0.413571  0.045553  0.452014  0.318193  0.879160  0.255178  0.554708
# 3   0.494920  0.602795  0.695493  0.553188  0.125612  0.548128  0.032606
# 4   0.689634  0.200942  0.558621  0.099504  0.247093  0.645387  0.536315
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.710314  0.054353  0.207234  0.040629  0.981967  0.284122  0.924552
# 96  0.858793  0.064279  0.655846  0.283142  0.618513  0.343716  0.012841
# 97  0.695763  0.880524  0.662723  0.267522  0.745430  0.883479  0.032405
# 98  0.182970  0.751467  0.234264  0.726557  0.583261  0.703080  0.555898
# 99  0.736347  0.299841  0.902763  0.967651  0.112122  0.367076  0.432706
#
#            h         i         j         k         l         m         n  \
# ...

# %%
new_file.to_csv('new_file.csv',index=False,header=True)

# %%
data = pd.read_csv('new_file.csv')
print("Original 'new_file.csv' CSV Data: \n")
print(data)
data.pop('b')
print("\nCSV Data after deleting the column 'b':\n")
print(data)
# Out:
# Original 'new_file.csv' CSV Data:
#
#            a         b         c         d         e         f         g  \
# 0   0.813466  0.740831  0.591413  0.844582  0.451223  0.093426  0.046024
# 1   0.499812  0.633928  0.551171  0.448612  0.680644  0.467954  0.485881
# 2   0.413571  0.045553  0.452014  0.318193  0.879160  0.255178  0.554708
# 3   0.494920  0.602795  0.695493  0.553188  0.125612  0.548128  0.032606
# 4   0.689634  0.200942  0.558621  0.099504  0.247093  0.645387  0.536315
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.710314  0.054353  0.207234  0.040629  0.981967  0.284122  0.924552
# 96  0.858793  0.064279  0.655846  0.283142  0.618513  0.343716  0.012841
# 97  0.695763  0.880524  0.662723  0.267522  0.745430  0.883479  0.032405
# 98  0.182970  0.751467  0.234264  0.726557  0.583261  0.703080  0.555898
# 99  0.736347  0.299841  0.902763  0.967651  0.112122  0.367076  0.432706
#
# ...

# %%
data.to_csv('data.csv',index=False,header=True)

# %%
data = pd.read_csv('new_file.csv')
df =  data.drop("a", axis='columns')
print(df)
# Out:
#            b         c         d         e         f         g         h  \
# 0   0.740831  0.591413  0.844582  0.451223  0.093426  0.046024  0.359784
# 1   0.633928  0.551171  0.448612  0.680644  0.467954  0.485881  0.603357
# 2   0.045553  0.452014  0.318193  0.879160  0.255178  0.554708  0.873762
# 3   0.602795  0.695493  0.553188  0.125612  0.548128  0.032606  0.861865
# 4   0.200942  0.558621  0.099504  0.247093  0.645387  0.536315  0.837891
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.054353  0.207234  0.040629  0.981967  0.284122  0.924552  0.701340
# 96  0.064279  0.655846  0.283142  0.618513  0.343716  0.012841  0.229978
# 97  0.880524  0.662723  0.267522  0.745430  0.883479  0.032405  0.439106
# 98  0.751467  0.234264  0.726557  0.583261  0.703080  0.555898  0.358435
# 99  0.299841  0.902763  0.967651  0.112122  0.367076  0.432706  0.197968
#
#            i         j         k         l         m         n         o  \
# ...
